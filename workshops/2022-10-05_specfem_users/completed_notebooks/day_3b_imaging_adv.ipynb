# %% [markdown]
# # SPECFEM Users Workshop -- Day 3 (Oct. 7, 2022)
#
# # TO DO (ctrl+f `!!!`):
# - Add Day 3 slides (this cell)
# - Check model update equation (Section 3)
# - Explain difference between sensitivity kernel, misfit kernel, event kernel, gradient (section 3)
#
#
#
# ## Part 3b: Seismic Imaging (advanced)
#
# - In this notebook we perform a multi-event, multi-station 2D inversion
# - We will perform all book keeping tasks manually
# - At the end of the notebook, we perform the same inversion using SeisFlows
# - **Objective**: Illustrate the laborious book keeping required as inversion problems scale
# - These instructions should be run from inside the Docker container, using Jupyter Lab (see *Docker Preamble* in Day 0).
#
# -----------
#
# **Relevant Links:**
# - Day 3 Slides !!! ADD THIS !!!
# - Today's Notebook: https://github.com/adjtomo/adjdocs/blob/main/workshops/2022-10-05_specfem_users/day_3a_imaging_adv.ipynb
# - Completed Notebook: https://github.com/adjtomo/adjdocs/blob/main/workshops/2022-10-05_specfem_users/completed_notebooks/day_3a_imaging_adv.ipynb
# - Day 0 Notebook (Container Testing): https://github.com/adjtomo/adjdocs/blob/main/workshops/2022-10-05_specfem_users/completed_notebooks/day_0_container_testing.ipynb
# - Day 1A Notebook (Intro SPECFEM): https://github.com/adjtomo/adjdocs/blob/main/workshops/2022-10-05_specfem_users/completed_notebooks/day_1a_intro_specfem2d.ipynb
# - Day 1B Notebook (Fwd. Simulations): https://github.com/adjtomo/adjdocs/blob/main/workshops/2022-10-05_specfem_users/completed_notebooks/day_1b_forward_simulations.ipynb
# - Day 2A Notebook (Adj. Simulations): https://github.com/adjtomo/adjdocs/blob/main/workshops/2022-10-05_specfem_users/completed_notebooks/day_2a_kernels.ipynb
# - Day 3A Notebook (Simple Imaging): https://github.com/adjtomo/adjdocs/blob/main/workshops/2022-10-05_specfem_users/completed_notebooks/day_3a_imaging_simple.ipynb
#
#
# **Jupyter Quick Tips:**
#
# - **Run cells** one-by-one by hitting the $\blacktriangleright$ button at the top, or by hitting `Shift + Enter`
# - **Run all cells** by hitting the $\blacktriangleright\blacktriangleright$ button at the top, or by running `Run -> Run All Cells`
# - **Currently running cells** that are still processing will have a `[*]` symbol next to them
# - **Finished cells** will have a `[1]` symbol next to them. The number inside the brackets represents what order this cell has been run in.
# - Commands that start with `!` are Bash commands (i.e., commands you would run from the terminal)
# - Commands that start with `%` are Jupyter Magic commands.
#
# ----------------

# %% [markdown]
# # A Multi-event, Multi-station Inversion
#
# - Real seismic inversions use multiple events recorded at multiple stations to increase coverage and reduce nonuniqueness
# - Here we attempt a *multi-event* ($N=10$), multi-station ($S=10$) model update with the skills we have picked up in previous notebooks
# - The inversion workflow is as follows:
#     0) **data**: run $N$ forward simulations to generate *data* using target model ($m_{true}$) for $N$ events and $S$ stations
#     1) **synthetics**: run $N$ forward simulations to generate synthetics through starting model ($m_{init}$) for $N$ events and $S$ stations
#     2) **misfit**: quantify data-synthetic misfit ($\chi_{init}$) and generate adjoint sources for each source-receiver pair ($N\times S$ waveforms)
#     3) **kernels**: generate misfit kernels with $N$ adjoint simulation
#     4) **update**: scale gradient and update initial model to get trial model: $m_{try}$
#     5) **line search**: run $N$ forward simulations using trial model $m_{try}$ to get $N \times S$ new synthetic waveforms
#     6) **line search**: calculate misfit ($\chi_{try}$) and determine if misfit is reduced ($\chi_{try} < \chi_{init}$?)
#     7) **line search**: if misfit is not reduced ($\chi_{try} >=  \chi_{init}$), repeat steps 5-7 with newly scaled gradient
#     8) **line search**: if misfit is reduced, accept trial model as newly updated model ($m_{try} \rightarrow m_{01}$)
#     9) **finalize**: set newly updated model as initial model ($m_{01} \rightarrow m_{init}$) and repeat steps 1-9

# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from IPython.display import Image
from scipy.integrate import simps
from seisflows.tools.specfem import Model, read_fortran_binary, write_fortran_binary

# %% [markdown]
# ## 1) Set Up a SPECFEM2D Working Directory
#
# - We want to set up a clean working directory to run SPECFEM2D inside. This will help us preserve our cloned repository and reduce file clutter.
# - 10 sources, 10 receivers
# - Starting model: homogeneous halfspace
# - Target model: perturbation checkerboard.
# - **Objective**: Generate a misfit kernel and manually update a 2D model, quantify misfit
# - **NOTE:** We will work in `/home/scoped/work/day_3/inversion_example`. The following cells assume relative paths, so you must evaluate the '%cd' command below.

# %%
# Make sure we're in an empty working directory
! rm -rf /home/scoped/work/day_3/inversion_example
! mkdir -p /home/scoped/work/day_3/inversion_example
# %cd /home/scoped/work/day_3/inversion_example

# Setup SPECFEM2D working directory
! ln -s /home/scoped/specfem2d/bin .
! cp -r /home/scoped/specfem2d/EXAMPLES/Tape2007/DATA .
! mkdir OUTPUT_FILES
# Out:
# /home/scoped/work/day_3/inversion_example

# %% [markdown]
# ## 2) Target Model (checkerboard) Synthetics (n=100)
#
# - We use the Target checkerboard model used to generate 'data'
# - 10 sources and 10 stations with pre-defined locations
# - Set the Par_file to output Model files in Fortran binary which we will use for visualizations

# %%
# %cd /home/scoped/work/day_3/inversion_example

# Set up the Par_file
! cp -f DATA/Par_file_Tape2007_132rec_checker DATA/Par_file

! seisflows sempar -P DATA/Par_file save_model binary
! seisflows sempar -P DATA/Par_file setup_with_binary_database 1
! seisflows sempar -P DATA/Par_file use_existing_stations .true.
! seisflows sempar -P DATA/Par_file NSTEP 5000  # 4800 -> 5000 to match the other Par_file

# Ensure that we're using stations 1-10
! head -10 DATA/STATIONS_checker > DATA/STATIONS  

# Ensure that SPECFEM can find the checkerboard model by naming it correctly
! cp -f DATA/model_velocity.dat_checker DATA/proc000000_model_velocity.dat_input
# Out:
# SAVE_MODEL: default -> binary
# setup_with_binary_database: 0 -> 1
# use_existing_STATIONS: .true. -> .true.
# NSTEP: 4800 -> 5000

# %% [markdown]
# ### a) Visualize Experimental Setup
#
# - We plot the 10 sources and 10 receivers with text labels
# - Also plot the underlying checkerboard model to see where the perturbatiosn are
# - The initial model is a homogeneous halfspace and is **not** plotted here

# %%
def plot_sources_receivers(nevents=10):
    """
    Small code block to plot source-receiver geometry with text labels
    Assumes relative pathing
    """
    # Grab Station locations
    sta_x, sta_z = np.genfromtxt("DATA/STATIONS", dtype=float, usecols=[2, 3]).T
    
    # Grab Event locations
    ev_x, ev_z = [], []
    for i in range(1, nevents+1):
        source_file = f"DATA/SOURCE_{i:0>3}"
        with open(source_file, "r") as f:
            lines = f.readlines()
        # Trying to break apart the following line
        # 'xs = 299367.72      # source location x in meters\n'
        xs = float(lines[2].split("=")[1].split("#")[0].strip())
        zs = float(lines[3].split("=")[1].split("#")[0].strip())

        ev_x.append(xs)
        ev_z.append(zs)
        
    # Plot SOURCES and STATIONS geometry
    for i, (x, z) in enumerate(zip(ev_x, ev_z)):
        plt.scatter(x, z, c="y", marker="*", edgecolor="k", s=50)
        plt.text(x, z, f"S{i+1:0>2}", fontsize=9, c="g")  # SOURCE numbering starts at 1
    for i, (x, z) in enumerate(zip(sta_x, sta_z)):
        plt.scatter(x, z, c="c", marker="v", s=40, edgecolor="k")
        plt.text(x, z, f"R{i:0>2}", fontsize=9)
        
    # Finalize plot labels
    plt.xlabel("X [m]")
    plt.ylabel("Z [m]")
    plt.xlim([0, 480E3])
    plt.ylim([0, 480E3])
    plt.title("SOURCE-RECEIVER GEOMETRY")
    
    
# Load and plot checkerboard model
data = np.genfromtxt("DATA/model_velocity.dat_checker", dtype=float, usecols=[1,2,4,5])
chkbd_x, chkbd_z, chkbd_vp, chkbd_vs = data.T
plt.tricontourf(chkbd_x, chkbd_z, chkbd_vp, levels=125, cmap="seismic_r", alpha=0.1)

# Plot sources and receivers on top
plot_sources_receivers()
plt.show()

# %% [markdown]
# ### b) Running the Forward Solver
#
# - We need to run the forward solver once per event (i.e., 10 times)
# - Each time we run SPECFEM, it overwrites existing files in the OUTPUT_FILES/ directory
# - In order to retain files, we need to do some file management after each forward simulation
# - We use Python for control flow but this can easily be accomplished using other languages
# - We define a re-usable function below to take care of looping through events and book keeping
# - **NOTE**: We really only have to run the mesher once to set up the database. Here we do not, but in 3D you will want to skip that step.

# %%
def run_fwd_mesher_solver(ntask, save_synthetics, save_forward=False):
    """
    Run the mesher and solver `ntask` times. Save the resulting synthetics
    to path `save_synthetics`. Assumes relative pathing.
        
    :type ntask: int
    :param ntask: number of sources to run
    :type save_synthetics: str
    :param save_synthetics: relative directory name to save synthetics to
    """
    print(f"Generating synthetics for {ntask} sources")
    
    # Run `ntask` forward simulations using Target model, generating 'data' for S stations. 
    for i in range(1, ntask + 1):
        # Select the task/source to run mesher/sovler with
        source_fid = f"SOURCE_{i:0>3}"
        source_path = f"DATA/{source_fid}"
        print(f"Running mesher and solver for {source_fid}")

        # Set the correct source for SPECFEM to find
        if os.path.exists("DATA/SOURCE"):
            os.remove("DATA/SOURCE")
        shutil.copy(source_path, "DATA/SOURCE")

        # Run xmeshfem and xspecfem 
        ! mpirun -n 1 bin/xmeshfem2D > OUTPUT_FILES/output_mesher.txt
        ! mpirun -n 1 bin/xspecfem2D > OUTPUT_FILES/output_solver.txt

        # Move the just-generated synthetic waveforms so they don't get overwritten
        synthetics_dir = os.path.join(source_fid, save_synthetics)
        if os.path.exists(synthetics_dir):
            shutil.rmtree(synthetics_dir)
        os.makedirs(synthetics_dir)
        for src in glob("OUTPUT_FILES/*.semd"):
            dst = os.path.join(source_fid, save_synthetics, os.path.basename(src))
            os.rename(src, dst)
        
        # Save forward arrays stored on disk if requested
        if save_forward:
            print(f"saving forward arrays {source_fid}")
            save_fwd_dir = os.path.join(source_fid, "SAVE_FORWARD")
            if not os.path.exists(save_fwd_dir):
                os.makedirs(save_fwd_dir)
            # Save fwd arrays are the last frame and boundary conditions
            fid_templates = ["lastframe_elastic*.bin", "absorb_elastic_*.bin"]
            for fid in fid_templates:
                for src in glob(f"OUTPUT_FILES/{fid}"):
                    dst = os.path.join(save_fwd_dir, os.path.basename(src))
                    os.rename(src, dst)
        
    print("Finished generating synthetics")

# %%
run_fwd_mesher_solver(ntask=10, save_synthetics="TARGET", save_forward=False)
# Out:
# Generating synthetics for 10 sources
# Running mesher and solver for SOURCE_001
# Running mesher and solver for SOURCE_002
# Running mesher and solver for SOURCE_003
# Running mesher and solver for SOURCE_004
# Running mesher and solver for SOURCE_005
# Running mesher and solver for SOURCE_006
# Running mesher and solver for SOURCE_007
# Running mesher and solver for SOURCE_008
# Running mesher and solver for SOURCE_009
# Running mesher and solver for SOURCE_010
# Finished generating synthetics

# %% [markdown]
# ## 3) Initial Model Synthetics
#
# - Now we'll generate synthetics through a homogeneous halfspace initial model
# - **IMPORTANT**: We need to save the forward wavefield (parameter `SAVE_FORWARD`) from the forward simulation of each $N$ events.
# - The saved forward wavefield is a snapshot of the forward wavefield at the last time step
# - The saved forward wavefield is used to reconstruct the forward wavefield during an adjoint simulation
# - For large domains (and especially in 3D), saved forward wavefields are **large** files (on the order of GB)
# - It is *not* preferable to save these large files for extended periods of time
# - We will follow that practice here by deleting the forward wavefield after each adjoint simulation

# %%
# %cd /home/scoped/work/day_3/inversion_example

# Re-set the SPECFEM2D Par_file which is set up for the Initial model
! cp -f DATA/Par_file_Tape2007_onerec DATA/Par_file

# Edit Par_file to get the correct output files for Initial model
! seisflows sempar -P DATA/Par_file save_model binary
! seisflows sempar -P DATA/Par_file setup_with_binary_database 1
! seisflows sempar -P DATA/Par_file use_existing_stations .true.
! seisflows sempar -P DATA/Par_file save_forward .true.

# Run mesher and solver for the Target model and 10 sources. 
# Also save forward arrays for subsequent adjoint simulations
run_fwd_mesher_solver(ntask=10, save_synthetics="SYNTHETIC", save_forward=True)
# Out:
# /home/scoped/work/day_3/inversion_example
# SAVE_MODEL: default -> binary
# setup_with_binary_database: 0 -> 1
# use_existing_STATIONS: .false. -> .true.
# SAVE_FORWARD: .false. -> .true.
# Generating synthetics for 10 sources
# Running mesher and solver for SOURCE_001
# saving forward arrays SOURCE_001
# Running mesher and solver for SOURCE_002
# saving forward arrays SOURCE_002
# Running mesher and solver for SOURCE_003
# saving forward arrays SOURCE_003
# Running mesher and solver for SOURCE_004
# saving forward arrays SOURCE_004
# Running mesher and solver for SOURCE_005
# saving forward arrays SOURCE_005
# Running mesher and solver for SOURCE_006
# saving forward arrays SOURCE_006
# Running mesher and solver for SOURCE_007
# saving forward arrays SOURCE_007
# Running mesher and solver for SOURCE_008
# saving forward arrays SOURCE_008
# Running mesher and solver for SOURCE_009
# saving forward arrays SOURCE_009
# Running mesher and solver for SOURCE_010
# saving forward arrays SOURCE_010
# Finished generating synthetics

# %% [markdown]
# ## 4) Quantify Misfit, Generate Adjoint Sources for Initial Model
#
# - We want to quantify misfit for all $N \times S$ waveforms
# - We also want to generate $N \times S$ adjoint sources for subsequent adjoint simulations
# - We'll use a waveform difference misfit for simplicity
# - Misfit: $ \chi = \frac{1}{2} \int [d(t)-s(t)]^2 dt~$
# - Adjoint Source: $f^\dagger (t) = s(t) - d(t)$
# - We'll define a re-usable Python function to calculate misfit and generate adjoint sources

# %%
def quantify_misfit_single(data_fid, syn_fid): 
    """
    Quantify misfit and generate adjoint source w/ waveform difference
    For a single source-receiver pair
    
    :type data_fid: str
    :param data_fid: filename and path to data array
    :type syn_fid: str
    :param syn_fid: filename and path to synthetic array
    """
    # Load data into NumPy arrays
    t_data, d_data = np.loadtxt(data_fid).T
    t_syn, d_syn = np.loadtxt(syn_fid).T
    
    # dt represents the time step
    dt = t_syn[1] - t_syn[0] 
    
    # Calculate waveform difference misfit
    misfit = 1/2 * simps((d_data - d_syn)**2, dx=dt)
    
    # Create the time-amplitude array for adjoint source
    d_adj = d_data - d_syn
    adj_src = np.vstack((t_syn, d_adj)).T
    
    return misfit, adj_src    


def quantify_misfit(misfit_file, write_adjsrc, syn_dir="SYNTHETIC"):
    """
    Quantify Misfit for all sources available
    
    :type write_misfit: str
    :param write_misfit: file name to write misfit to
    :type write_adjsrc: bool
    :param write_adjsrc: choose whether or not to save adjoint sources
    :type syn_dir: str
    :param syn_dir: relative path to directory where synthetics are stored
    """
    for src in sorted(glob("SOURCE_???")):
        print(f"Quantifying misfit for {src}")

        # Set up directories to store misfit and adjoint sources
        # Make sure we're writing to fresh files/directories
        misfit_path = os.path.join(src, misfit_file)
        if os.path.exists(misfit_path):
            os.remove(misfit_path)
                
        if write_adjsrc:
            adj_src_dir = os.path.join(src, "ADJOINT_SOURCES")
            if os.path.exists(adj_src_dir):
                shutil.rmtree(adj_src_dir)
            os.makedirs(adj_src_dir)

        # Loop through each of the synthetic waveforms to get file names
        for syn_fid in sorted(glob(os.path.join(src, syn_dir, "*"))):
            # e.g., AA.S000001.BXY.semd
            fid_base = os.path.basename(syn_fid)
            data_fid = os.path.join(src, "TARGET", fid_base)
            
            misfit, adj_src = quantify_misfit_single(data_fid, syn_fid)
            print(f"\t{fid_base}; MISFIT={misfit:.3E}")
            
            # Write misfit to file
            with open(misfit_path, "a") as f:
                f.write(f"{misfit}\n")

            # Write adjoint source to file
            # Note that SPECFEM expects adjoint sources to be suffixed '.adj.
            if write_adjsrc:
                np.savetxt(os.path.join(adj_src_dir, fid_base.replace("semd", "adj")), adj_src)
                
def plot_waveforms(t, data, labels, colors):
    """Re-usable function to plot synthetic waveforms"""
    for i, d in enumerate(data):
        plt.plot(t, d, c=colors[i], label=labels[i])
    plt.xlabel("Time [s]")
    plt.ylabel("Displacement [m]")
    plt.legend()

# %%
# Run misfit quantification for initial model
quantify_misfit(misfit_file="MISFIT_INIT.txt", write_adjsrc=True, synthetic_dir="SYNTHETIC")
# Out:
# Quantifying misfit for SOURCE_001
# 	AA.S000000.BXY.semd; MISFIT=1.453E-03
# 	AA.S000001.BXY.semd; MISFIT=2.779E-03
# 	AA.S000002.BXY.semd; MISFIT=2.681E-03
# 	AA.S000003.BXY.semd; MISFIT=3.362E-03
# 	AA.S000004.BXY.semd; MISFIT=1.865E-03
# 	AA.S000005.BXY.semd; MISFIT=3.019E-03
# 	AA.S000006.BXY.semd; MISFIT=6.479E-04
# 	AA.S000007.BXY.semd; MISFIT=3.854E-03
# 	AA.S000008.BXY.semd; MISFIT=1.535E-03
# 	AA.S000009.BXY.semd; MISFIT=2.521E-03
# Quantifying misfit for SOURCE_002
# 	AA.S000000.BXY.semd; MISFIT=7.489E-04
# 	AA.S000001.BXY.semd; MISFIT=2.291E-05
# 	AA.S000002.BXY.semd; MISFIT=1.178E-04
# 	AA.S000003.BXY.semd; MISFIT=5.811E-04
# 	AA.S000004.BXY.semd; MISFIT=7.057E-04
# 	AA.S000005.BXY.semd; MISFIT=3.858E-04
# 	AA.S000006.BXY.semd; MISFIT=2.904E-04
# 	AA.S000007.BXY.semd; MISFIT=4.175E-04
# 	AA.S000008.BXY.semd; MISFIT=6.777E-05
# 	AA.S000009.BXY.semd; MISFIT=7.442E-04
# Quantifying misfit for SOURCE_003
# 	AA.S000000.BXY.semd; MISFIT=1.634E-03
# 	AA.S000001.BXY.semd; MISFIT=1.572E-03
# 	AA.S000002.BXY.semd; MISFIT=2.182E-04
# 	AA.S000003.BXY.semd; MISFIT=1.928E-04
# 	AA.S000004.BXY.semd; MISFIT=2.176E-03
# 	AA.S000005.BXY.semd; MISFIT=2.007E-03
# 	AA.S000006.BXY.semd; MISFIT=1.069E-03
# 	AA.S000007.BXY.semd; MISFIT=1.478E-03
# 	AA.S000008.BXY.semd; MISFIT=1.726E-03
# 	AA.S000009.BXY.semd; MISFIT=1.557E-03
# Quantifying misfit for SOURCE_004
# 	AA.S000000.BXY.semd; MISFIT=1.830E-03
# 	AA.S000001.BXY.semd; MISFIT=1.474E-03
# 	AA.S000002.BXY.semd; MISFIT=3.435E-03
# 	AA.S000003.BXY.semd; MISFIT=1.447E-03
# 	AA.S000004.BXY.semd; MISFIT=8.716E-04
# 	AA.S000005.BXY.semd; MISFIT=1.506E-03
# 	AA.S000006.BXY.semd; MISFIT=2.867E-04
# 	AA.S000007.BXY.semd; MISFIT=2.245E-03
# 	AA.S000008.BXY.semd; MISFIT=1.698E-04
# 	AA.S000009.BXY.semd; MISFIT=2.478E-03
# Quantifying misfit for SOURCE_005
# 	AA.S000000.BXY.semd; MISFIT=2.927E-05
# 	AA.S000001.BXY.semd; MISFIT=5.372E-05
# 	AA.S000002.BXY.semd; MISFIT=3.599E-04
# 	AA.S000003.BXY.semd; MISFIT=3.011E-03
# 	AA.S000004.BXY.semd; MISFIT=1.701E-04
# 	AA.S000005.BXY.semd; MISFIT=1.421E-05
# 	AA.S000006.BXY.semd; MISFIT=3.278E-05
# 	AA.S000007.BXY.semd; MISFIT=5.119E-05
# 	AA.S000008.BXY.semd; MISFIT=2.607E-04
# 	AA.S000009.BXY.semd; MISFIT=3.931E-06
# Quantifying misfit for SOURCE_006
# 	AA.S000000.BXY.semd; MISFIT=9.769E-04
# 	AA.S000001.BXY.semd; MISFIT=1.918E-06
# 	AA.S000002.BXY.semd; MISFIT=3.380E-04
# 	AA.S000003.BXY.semd; MISFIT=3.998E-05
# 	AA.S000004.BXY.semd; MISFIT=3.727E-04
# 	AA.S000005.BXY.semd; MISFIT=1.042E-04
# 	AA.S000006.BXY.semd; MISFIT=3.353E-05
# 	AA.S000007.BXY.semd; MISFIT=7.718E-06
# 	AA.S000008.BXY.semd; MISFIT=1.053E-04
# 	AA.S000009.BXY.semd; MISFIT=4.863E-04
# Quantifying misfit for SOURCE_007
# 	AA.S000000.BXY.semd; MISFIT=2.273E-04
# 	AA.S000001.BXY.semd; MISFIT=9.695E-04
# 	AA.S000002.BXY.semd; MISFIT=4.934E-04
# 	AA.S000003.BXY.semd; MISFIT=3.203E-04
# 	AA.S000004.BXY.semd; MISFIT=1.007E-03
# 	AA.S000005.BXY.semd; MISFIT=7.716E-04
# 	AA.S000006.BXY.semd; MISFIT=1.265E-03
# 	AA.S000007.BXY.semd; MISFIT=2.117E-04
# 	AA.S000008.BXY.semd; MISFIT=1.551E-03
# 	AA.S000009.BXY.semd; MISFIT=5.167E-05
# Quantifying misfit for SOURCE_008
# 	AA.S000000.BXY.semd; MISFIT=9.690E-05
# 	AA.S000001.BXY.semd; MISFIT=7.973E-06
# 	AA.S000002.BXY.semd; MISFIT=1.467E-04
# 	AA.S000003.BXY.semd; MISFIT=2.068E-03
# 	AA.S000004.BXY.semd; MISFIT=3.275E-04
# 	AA.S000005.BXY.semd; MISFIT=8.640E-05
# 	AA.S000006.BXY.semd; MISFIT=1.805E-04
# 	AA.S000007.BXY.semd; MISFIT=9.112E-06
# 	AA.S000008.BXY.semd; MISFIT=5.279E-04
# 	AA.S000009.BXY.semd; MISFIT=2.012E-05
# Quantifying misfit for SOURCE_009
# 	AA.S000000.BXY.semd; MISFIT=4.363E-05
# 	AA.S000001.BXY.semd; MISFIT=2.189E-03
# 	AA.S000002.BXY.semd; MISFIT=4.103E-05
# 	AA.S000003.BXY.semd; MISFIT=4.012E-04
# 	AA.S000004.BXY.semd; MISFIT=1.160E-04
# 	AA.S000005.BXY.semd; MISFIT=4.449E-04
# 	AA.S000006.BXY.semd; MISFIT=2.775E-03
# 	AA.S000007.BXY.semd; MISFIT=2.852E-04
# 	AA.S000008.BXY.semd; MISFIT=1.822E-03
# 	AA.S000009.BXY.semd; MISFIT=3.354E-05
# Quantifying misfit for SOURCE_010
# 	AA.S000000.BXY.semd; MISFIT=1.377E-05
# 	AA.S000001.BXY.semd; MISFIT=7.354E-07
# 	AA.S000002.BXY.semd; MISFIT=6.179E-04
# 	AA.S000003.BXY.semd; MISFIT=2.421E-03
# 	AA.S000004.BXY.semd; MISFIT=2.176E-04
# 	AA.S000005.BXY.semd; MISFIT=1.491E-04
# 	AA.S000006.BXY.semd; MISFIT=1.443E-05
# 	AA.S000007.BXY.semd; MISFIT=2.510E-04
# 	AA.S000008.BXY.semd; MISFIT=1.467E-04
# 	AA.S000009.BXY.semd; MISFIT=2.980E-05

# %% [markdown]
# #### Understanding misfit quantification
# - For each of our $N$ sources we have quantified misfit for $S$ stations
# - Each synthetic has a corresponding adjoint source, which is stored in `SOURCE_???/ADJOINT_SOURCE`
# - Each adjoint source is equal to the waveform difference between data and synthetic
# - Each adjoint source has a corresponding misfit value
# - Misfit values are stored in a text file which can be summed to calculate the overall **event misfit**
# - The adjoint sources will be used to run $N$ adjoint simulations
# - The misfit value will be used to determine if misfit is reduced during the line search

# %%
# We can take a look at the files we just created
! ls SOURCE_001
! echo 
! echo "> ADJOINT SOURCES"
! ls SOURCE_001/ADJOINT_SOURCES
! echo 
! echo "> SOURCE_001/ADJOINT_SOURCES/AA.S000000.BXY.adj"
! head SOURCE_001/ADJOINT_SOURCES/AA.S000000.BXY.adj
! echo
! echo "> SOURCE_001/MISFIT_INIT.txt"
! head SOURCE_001/MISFIT_INIT.txt
# Out:
# ADJOINT_SOURCES  MISFIT_INIT.txt  SAVE_FORWARD	SYNTHETIC  TARGET
#
# > ADJOINT SOURCES
# AA.S000000.BXY.adj  AA.S000003.BXY.adj	AA.S000006.BXY.adj  AA.S000009.BXY.adj
# AA.S000001.BXY.adj  AA.S000004.BXY.adj	AA.S000007.BXY.adj
# AA.S000002.BXY.adj  AA.S000005.BXY.adj	AA.S000008.BXY.adj
#
# > SOURCE_001/ADJOINT_SOURCES/AA.S000000.BXY.adj
# -4.800000000000000000e+01 0.000000000000000000e+00
# -4.793999999999999773e+01 0.000000000000000000e+00
# -4.788000000000000256e+01 0.000000000000000000e+00
# -4.782000000000000028e+01 0.000000000000000000e+00
# -4.775999999999999801e+01 0.000000000000000000e+00
# -4.770000000000000284e+01 0.000000000000000000e+00
# -4.764000000000000057e+01 0.000000000000000000e+00
# -4.757999999999999829e+01 0.000000000000000000e+00
# -4.752000000000000313e+01 0.000000000000000000e+00
# -4.746000000000000085e+01 0.000000000000000000e+00
#
# > SOURCE_001/MISFIT_INIT.txt
# 0.0014528338515827628
# 0.0027791449963558233
# 0.0026805867007072
# 0.003362180404050814
# 0.0018646699327360783
# 0.003018752702325197
# 0.0006478914530926254
# 0.0038540677661830338
# 0.0015348926025808422
# 0.002521409384520838

# %%
# Plot an example of data, synthetic and adjoint source
t_init, d_init = np.loadtxt("SOURCE_001/SYNTHETIC/AA.S000000.BXY.semd").T
t_true, d_true = np.loadtxt("SOURCE_001/TARGET/AA.S000000.BXY.semd").T
t_adjs, d_adjs = np.loadtxt("SOURCE_001/ADJOINT_SOURCES/AA.S000000.BXY.adj").T

plot_waveforms(t=t_init, data=[d_init, d_true, d_adjs],
               labels=["initial", "target", "adjsrc"],
               colors=["r", "k", "g"])

plt.title("Initial vs. Target Model Synthetics")
plt.show()

# %%
plot_waveforms(t=t_init, data=[d_init, d_true, d_adjs],
               labels=["initial", "target", "adjsrc"],
               colors=["r", "k", "g"])
plt.xlim([45,145])
plt.title("Initial vs. Target Model Synthetics")
plt.show()

# %% [markdown]
# ## 5) Run Adjoint Simulations for Event Kernels
#
# - Now we need to run the adjoint simulations to generate event kernels
# - Event kernels tell us what parts of the model are sensitive to the misfit function for **EACH** event
# - Adjoint simulations take $S$ adjoint sources as input
# - **NOTE**: We need to place the adjoint sources in the correct location and also tell SPECFEM that we are running an adjoint simulation
# - SPECFEM expects adjoint sources in the `SEM/` directory, and formatted exactly the same as its output synthetics
# - We define a Python function below to run the adjoint solver and take care of book keeping for adjoint sources and kernels

# %%
def run_adj_solver():
    """
    Counterpart to `run_fwd_mesher_solver`, runs adjoint simulations for `ntask` events
    and saves the resulting kernels. Assumes relative paths
    """
    ntask = len(glob("SOURCE_???"))
    print(f"Running adjoint simulations for {ntask} events")
    
    for i in range(1, ntask + 1):
        # Choose the task/source to run mesher/sovler with
        source_fid = f"SOURCE_{i:0>3}"
        source_path = f"DATA/{source_fid}"
        print(f"Running adjoint simulation for {source_fid}")

        # Set the correct source for SPECFEM to find
        if os.path.exists("DATA/SOURCE"):
            os.remove("DATA/SOURCE")
        shutil.copy(source_path, "DATA/SOURCE")
                
        # Symlink adjoint sources so SPECFEM can find them
        if os.path.islink("SEM"):
            os.remove("SEM")
        os.symlink(os.path.join(source_fid, "ADJOINT_SOURCES"), "SEM")
        
        # Copy the saved forward array so that SPECFEM can find it
        for src in glob(os.path.join(source_fid, "SAVE_FORWARD", "*")):
            dst = os.path.join("OUTPUT_FILES", os.path.basename(src))
            if os.path.exists(dst):
                os.remove(dst)
            shutil.copy(src, dst)
            
        # Run the adjoint simulation
        ! mpirun -n 1 bin/xspecfem2D > OUTPUT_FILES/adjoint_solver.txt
        
        # Move the resulting event kernel to disk
        kernel_dir = os.path.join(source_fid, "KERNELS")
        if os.path.exists(kernel_dir):
            shutil.rmtree(kernel_dir)
        os.makedirs(kernel_dir)
        for src in glob("OUTPUT_FILES/*kernel.bin"):
            dst = os.path.join(kernel_dir, os.path.basename(src))
            os.rename(src, dst)
            
    print("Finished")

# %%
# Set up the Par_file to run an adjoint simulation (type 3) 
# and output kernels in expected output (FORTRAN binary)
! seisflows sempar -P DATA/Par_file simulation_type 3
! seisflows sempar -P DATA/Par_file save_ASCII_kernels .false.

# Run adjoint simluation for each N sources. This may take a while
run_adj_solver()
# Out:
# SIMULATION_TYPE: 3 -> 3
# save_ASCII_kernels: .false. -> .false.
# Running adjoint simulations for 10 events
# Running adjoint simulation for SOURCE_001
# Finished
# Running adjoint simulation for SOURCE_002
# Finished
# Running adjoint simulation for SOURCE_003
# Finished
# Running adjoint simulation for SOURCE_004
# Finished
# Running adjoint simulation for SOURCE_005
# Finished
# Running adjoint simulation for SOURCE_006
# Finished
# Running adjoint simulation for SOURCE_007
# Finished
# Running adjoint simulation for SOURCE_008
# Finished
# Running adjoint simulation for SOURCE_009
# Finished
# Running adjoint simulation for SOURCE_010
# Finished

# %% [markdown]
# ## 6) Sum Event Kernels and Scale Gradient
#
# - Now we have $N$=10 event kernels, each representing misfit sensitivity for each of the $N$ events
# - We need to sum the *event kernels* into a *misfit kernel*, which represents misfit sensitivity for **all** $N$ events
# - We can use the `xcombine_sem` executable to sum these kernels
# - We will also need to scale the misfit kernel before perturbing the initial model

# %%
# First we need to tell SPECFEM where all our kernel files are by 
# listing paths in an input file
with open("kernel_paths.txt", "w") as f:
    for fid in sorted(glob("SOURCE_???/KERNELS")):
        f.write(f"{os.path.abspath(fid)}\n")

# Make a directory to store gradient files
! mkdir GRADIENT

# mpirun -n NPROC bin/xcombine_sem KERNEL_NAMES INPUT_FILE OUTPUT_DIR*
! mpirun -n 1 bin/xcombine_sem alpha_kernel,beta_kernel kernel_paths.txt GRADIENT 

# Rename 'alpha' to Vp and 'beta' to Vs for easier name recognition
for src in glob("GRADIENT/*"):
    if "alpha" in src:
        os.rename(src, src.replace("alpha", "vp"))
    elif "beta" in src:
        os.rename(src, src.replace("beta", "vs"))
# Out:
#  Running XCOMBINE_SEM
#
#  reading in array for: alpha_kernel
#                 1  out of           10
#  reading in array for: alpha_kernel
#                 2  out of           10
#  reading in array for: alpha_kernel
#                 3  out of           10
#  reading in array for: alpha_kernel
#                 4  out of           10
#  reading in array for: alpha_kernel
#                 5  out of           10
#  reading in array for: alpha_kernel
#                 6  out of           10
#  reading in array for: alpha_kernel
#                 7  out of           10
#  reading in array for: alpha_kernel
#                 8  out of           10
#  reading in array for: alpha_kernel
#                 9  out of           10
#  reading in array for: alpha_kernel
#                10  out of           10
#  writing sum: alpha_kernel
#
#  reading in array for: beta_kernel
#                 1  out of           10
#  reading in array for: beta_kernel
#                 2  out of           10
#  reading in array for: beta_kernel
#                 3  out of           10
#  reading in array for: beta_kernel
#                 4  out of           10
#  reading in array for: beta_kernel
#                 5  out of           10
#  reading in array for: beta_kernel
#                 6  out of           10
#  reading in array for: beta_kernel
#                 7  out of           10
#  reading in array for: beta_kernel
#                 8  out of           10
#  reading in array for: beta_kernel
#                 9  out of           10
#  reading in array for: beta_kernel
#                10  out of           10
#  writing sum: beta_kernel

# %% [markdown]
# ### a) Visualizing the Event Kernel
#
# - We can visualize the gradient using SeisFlows utilities
# - Note that this visualization technique is only viable for SPECFEM2D
# - Gradient amplitudes are stored in the output Fortran binary files
# - We only plot the Vs Kernel here but the Gradient is a linear array of Vp and Vs

# %%
# In this cell we'll scale the gradient (Vp and Vs only) by GTG^-1
x = read_fortran_binary("DATA/proc000000_x.bin")
z = read_fortran_binary("DATA/proc000000_z.bin")
vs_kernel = read_fortran_binary("GRADIENT/proc000000_vs_kernel.bin")

boundary_value = 2E-10  # <- change this value to adjust the colorscale

# Plot the kernel
plt.tricontourf(x, z, vs_kernel, levels=125, cmap="seismic_r", 
                vmin=-1*boundary_value, vmax=boundary_value)
plt.colorbar()

plot_sources_receivers()
plt.title("Gradient Vs")
# Out:
# Text(0.5, 1.0, 'Gradient Vs')

# %% [markdown]
# #### Understanding the above figure
#
# - Above we are seeing the Misfit kernel for the parameter Vs
# - The misfit kernel represents sensitivity of the misfit function to changes in model parameter Vs
# - Red colors tell us that the inital model is **too fast** (i.e., we need to slow down the initial model)
# - Blue colors tell us that the initial model is **too slow** (i.e., we need to speed up the initial model)
# - We can see large amplitudes directly around source locations (e.g., S01 and S09 at the bottom)
# - These amplitudes are due to the numerical discretization of our grid, and the fact that we implement point source forces
# - We can use regularization to remove the strong influence of the near-source region
# - Our chosen regularization technique is smoothing

# %% [markdown]
# ## 7) Smoothing/Regularizing Kernels
#
# - We can use regularization to smooth out the gradient to get a more conservative picture of model update
# - We use the `xsmooth_sem` executable to smooth our kernels
# - We should choose smoothing length based on the shortest period of our data
# - Because we know the target model, we smooth conservatively to the length scale of the checkerboards ($\Gamma$=50km)
# - The SPECFEM smoothing code convolves the kernel with a Gaussian. We are allowed to choose the half-width of the Gaussian
# - The relationship between half-width and full-width is $\Gamma\approx2.355\sigma$, so we choose $\sigma$=20km
#
#  The usage of `xsmooth_sem` is given as
#  ```bash
#  USAGE:  mpirun -np NPROC bin/xsmooth_sem SIGMA_H SIGMA_V KERNEL_NAME INPUT_DIR OUPUT_DIR GPU_MODE
#  ```
#  We will need to choose values and directories to make this work
#   - `SIGMA_H`: Horizontal smoothing length [m] representing the horizontal half-width of the Gaussian
#   - `SIGMA_Z`: Vertical smoothing length [m] representing the vertical half-width of the Gaussian
#   - `KERNEL_NAME`: The name of the kernel we want to smooth. Must match filename, so `proc000000_vs_kernel.bin` will correspond to kernel name `vs_kernel`
#   - `INPUT_DIR`: where SPECFEM can find the kernel files
#   - `OUTPUT_DIR`: Where SPECFEM should output the SMOOTHED kernels
#   - `GPU_MODE`: Use GPU acceleration to speed up the smoothing operation (.true. or .false.)

# %%
# SPECFEM Requires that some of the model files be discoverable alongside the kernels
! cp -f GRADIENT/*.bin DATA/

! mpirun -n 1 bin/xsmooth_sem 20000 20000 vs_kernel DATA/ GRADIENT/ .false.
! mpirun -n 1 bin/xsmooth_sem 20000 20000 vp_kernel DATA/ GRADIENT/ .false.
# Out:
#  Running XSMOOTH_SEM on           1 processors
#  command line arguments:
#    smoothing sigma_h , sigma_v                :    20000.0000       20000.0000
#    smoothing scalelengths horizontal, vertical:    56568.5430       56568.5430
#    input dir : DATA/
#    output dir: GRADIENT/
#
#
#  Scaling values: min/max =    628318528.       2.51327462E+09
#  written: GRADIENT//proc000000_vs_kernel_smooth.bin
#
#   Min / Max data value before smoothing =    1.80248611E-18   6.13813556E-10 for vs_kernel
#   Min / Max data value after smoothing  =    3.76721791E-18   5.28358850E-11 for vs_kernel
#  Computation time with CPU:   21.9838600
#  Running XSMOOTH_SEM on           1 processors
#  command line arguments:
#    smoothing sigma_h , sigma_v                :    20000.0000       20000.0000
#    smoothing scalelengths horizontal, vertical:    56568.5430       56568.5430
#    input dir : DATA/
#    output dir: GRADIENT/
#
#
#  Scaling values: min/max =    628318528.       2.51327462E+09
#  written: GRADIENT//proc000000_vp_kernel_smooth.bin
#
#   Min / Max data value before smoothing =    0.00000000       0.00000000     for vp_kernel
#   Min / Max data value after smoothing  =    0.00000000       0.00000000     for vp_kernel
#  Computation time with CPU:   18.6284294

# %%
# The smoothing operation has created new files with the 'smooth' tag
vs_kernel_smooth = read_fortran_binary("GRADIENT/proc000000_vs_kernel_smooth.bin")

boundary_value = 8E-11  # <- change this value to adjust the colorscale

# Plot the kernel
plt.tricontourf(x, z, vs_kernel_smooth, levels=125, cmap="seismic_r", 
                vmin=-1*boundary_value, vmax=boundary_value)
plt.colorbar()

plot_sources_receivers()
plt.title("Smoothed Gradient Vs")
# Out:
# Text(0.5, 1.0, 'Smoothed Gradient Vs')

# %% [markdown]
# #### Understanding the above figure
#
# - Above we see the smoothed misfit kernel
# - We have applied smoothing using a 2D Gaussian with half width equal to 20km
# - The regularization has removed the small-scale heterogeneity present in the raw gradient
# - The colors still represent the same quantities as before

# %% [markdown]
# ## 8) Scaling the Gradient
#
# - Again we'll need to **scale** the gradient before using it to perturb the initial model
# - As in Day 3a, we'll scale the gradient by [G$^T$G]$^{-1}$
# - We can then perturb the initial model by the scaled gradient to recover new synthetics

# %%
# Load in the regularized kernel
vp_kernel = read_fortran_binary("GRADIENT/proc000000_vs_kernel_smooth.bin")
vs_kernel = read_fortran_binary("GRADIENT/proc000000_vs_kernel_smooth.bin")

# The Gradient is a linear vector of kernels for each parameter
gradient = np.hstack((vp_kernel, vs_kernel))

# Calculate GTG^-1
gtg = np.dot(gradient, gradient)
gtg_inverse = gtg ** -1 
print(f"GTG^-1 = {gtg_inverse:.2f}")

# Scaling the gradient by GTG^-1
gradient = gradient * gtg_inverse
# Out:
# GTG^-1 = 59547680749611376.00

# %% [markdown]
# ## 9) Perturbing the Initial Model
#
# - We can perturb the initial model with the gradient to generate an update model ($m_{try}$)
# - We'll use this updated model to run forward simulations
# - We **only** update seismic velocity Vp and Vs. However during your own research, other quantities may be updated.
# - Users will need to determine what model parameters their misfit function is sensitive to
# - **Objective**: Quantify misfit of the new synthetics to determine if misfit has been reduced

# %%
# We will separate model files to keep things clean
! rm -rf MODEL_INIT
! mkdir MODEL_INIT
! rm -rf MODEL_01
! mkdir MODEL_01

# These files define a SPECFEM2D model. SPECFEM3D models will differ
for tag in ["x", "z", "rho", "vp", "vs", "NSPEC_ibool", "jacobian"]:
    src = f"DATA/proc000000_{tag}.bin"
    # Save the initial model to disk
    dst = f"MODEL_INIT/{os.path.basename(src)}"
    shutil.copy(src, dst)
    # Copy to Model 01 which will be overloaded by new parameters
    dst = f"MODEL_01/{os.path.basename(src)}"
    shutil.copy(src, dst)
    
# Load the initial model velocity so we can overload them
model_init_vp = read_fortran_binary("MODEL_INIT/proc000000_vp.bin")
model_init_vs = read_fortran_binary("MODEL_INIT/proc000000_vs.bin")

# Split the gradient by parameter
n = len(gradient) // 2
gradient_vp = gradient[:n]
gradient_vs = gradient[n:]

# Perturb the initial model by the gradient
model_01_vp = model_init_vp - gradient_vp
model_01_vs = model_init_vs - gradient_vs

# OVERWRITE Vp and Vs for Model 01 with perturbed model parameters
write_fortran_binary(model_01_vp, "MODEL_01/proc000000_vp.bin")
write_fortran_binary(model_01_vs, "MODEL_01/proc000000_vs.bin")

# %% [markdown]
# ### a) Checking Model Parameters
#
# - We can quickly determine if the update model is acceptable by checking min and max values
# - We use external knowledge to quantify whether the new model is acceptable
# - For example we know we cannot have negative velocity values for typical wavespeeds in Earth structure
# - External geological evidence might also help constrain expected velocity values

# %%
print(f"MODEL INIT Vs_min = {model_init_vs.min()}")
print(f"MODEL INIT Vs_max = {model_init_vs.max()}")
print(f"\nMODEL TRY Vs_min = {model_01_vs.min()}")
print(f"MODEL TRY Vs_max = {model_01_vs.max()}")
# Out:
# MODEL INIT Vs_min = 3500.0
# MODEL INIT Vs_max = 3500.0
#
# MODEL TRY Vs_min = -2388291.0
# MODEL TRY Vs_max = 3149754.5

# %% [markdown]
# Already we see that our velocity values are way out of spec. We will need to manually step back our gradient.
# In a real seismic inversion, this would be algorithmically determined, but for the sake of brevity we will
# simply scale back our gradient until we reach acceptable perturbation levels. Here we limit the largest value of $\alpha$ to be roughly 10\% of the initial model value

# %%
# Safe guard the gradient from overreaching
max_alpha = model_init_vs.mean() * 0.1  
gradient /= gradient.max()  # reset gradient to be scaled to 1
gradient *= max_alpha  # set a new alpha value as 10% of the velocity model

# Create new updated model parameters !!! WHY IS THIS POSITIVE AND NOT NEGATIVE? !!!
model_01_vp = model_init_vp + gradient_vp
model_01_vs = model_init_vs + gradient_vs

# OVERWRITE Vp and Vs for Model 01 with perturbed model parameters
write_fortran_binary(model_01_vp, "MODEL_01/proc000000_vp.bin")
write_fortran_binary(model_01_vs, "MODEL_01/proc000000_vs.bin")

print(f"MODEL TRY Vs_min = {model_01_vs.min()}")
print(f"MODEL TRY Vs_max = {model_01_vs.max()}")

# Plot the updated model
plt.tricontourf(x, z, model_01_vs, levels=125, cmap="RdYlBu")
plt.colorbar()

plot_sources_receivers()
plt.title("Model 01 Trial 1 Vs")
# Out:
# /home/scoped/work/day_3/inversion_example
# MODEL TRY Vs_min = 3039.596435546875
# MODEL TRY Vs_max = 3850.0
# Text(0.5, 1.0, 'Model 01 Trial 1 Vs')

# %% [markdown]
# ## 10) Run Forward Simulations with Updated Model
#
# - Now that we have a perturbed model (Model 01) we can use it to run forward simulations
# - We can calculate misfit for each of the new synthetics
# - We can compare the overall misfit of the initial model to Model 01
# - **Objective**: determine if we have reduced waveform misfit through our model perturbation

# %%
# Set the correct velocity model where SPECFEM expects it
for tag in ["x", "z", "rho", "vp", "vs", "NSPEC_ibool", "jacobian"]:
    src = f"MODEL_01/proc000000_{tag}.bin"
    dst = f"DATA/proc000000_{tag}.bin"
    if os.path.exists(dst):
        os.remove(dst)
    shutil.copy(src, dst)

# Reset the simulation type to forward, since we changed it during the adjoint simulation
! seisflows sempar -P DATA/Par_file simulation_type 1
! seisflows sempar -P DATA/Par_file model gll

run_fwd_mesher_solver(ntask=10, save_synthetics="SYNTHETIC_01", save_forward=False)
quantify_misfit(misfit_file="MISFIT_01.txt", write_adjsrc=False, syn_dir="SYNTHETIC_01")
# Out:
# SIMULATION_TYPE: 1 -> 1
# MODEL: gll -> gll
# Generating synthetics for 10 sources
# Running mesher and solver for SOURCE_001
# Running mesher and solver for SOURCE_002
# Running mesher and solver for SOURCE_003
# Running mesher and solver for SOURCE_004
# Running mesher and solver for SOURCE_005
# Running mesher and solver for SOURCE_006
# Running mesher and solver for SOURCE_007
# Running mesher and solver for SOURCE_008
# Running mesher and solver for SOURCE_009
# Running mesher and solver for SOURCE_010
# Finished generating synthetics
# Quantifying misfit for SOURCE_001
# 	AA.S000000.BXY.semd; MISFIT=1.453E-03
# 	AA.S000001.BXY.semd; MISFIT=2.779E-03
# 	AA.S000002.BXY.semd; MISFIT=2.681E-03
# 	AA.S000003.BXY.semd; MISFIT=3.362E-03
# 	AA.S000004.BXY.semd; MISFIT=1.865E-03
# 	AA.S000005.BXY.semd; MISFIT=3.019E-03
# 	AA.S000006.BXY.semd; MISFIT=6.479E-04
# 	AA.S000007.BXY.semd; MISFIT=3.854E-03
# 	AA.S000008.BXY.semd; MISFIT=1.535E-03
# 	AA.S000009.BXY.semd; MISFIT=2.521E-03
# Quantifying misfit for SOURCE_002
# 	AA.S000000.BXY.semd; MISFIT=7.489E-04
# 	AA.S000001.BXY.semd; MISFIT=2.291E-05
# 	AA.S000002.BXY.semd; MISFIT=1.178E-04
# 	AA.S000003.BXY.semd; MISFIT=5.811E-04
# 	AA.S000004.BXY.semd; MISFIT=7.057E-04
# 	AA.S000005.BXY.semd; MISFIT=3.858E-04
# 	AA.S000006.BXY.semd; MISFIT=2.904E-04
# 	AA.S000007.BXY.semd; MISFIT=4.175E-04
# 	AA.S000008.BXY.semd; MISFIT=6.777E-05
# 	AA.S000009.BXY.semd; MISFIT=7.442E-04
# Quantifying misfit for SOURCE_003
# 	AA.S000000.BXY.semd; MISFIT=1.634E-03
# 	AA.S000001.BXY.semd; MISFIT=1.572E-03
# 	AA.S000002.BXY.semd; MISFIT=2.182E-04
# 	AA.S000003.BXY.semd; MISFIT=1.928E-04
# 	AA.S000004.BXY.semd; MISFIT=2.176E-03
# 	AA.S000005.BXY.semd; MISFIT=2.007E-03
# 	AA.S000006.BXY.semd; MISFIT=1.069E-03
# 	AA.S000007.BXY.semd; MISFIT=1.478E-03
# 	AA.S000008.BXY.semd; MISFIT=1.726E-03
# 	AA.S000009.BXY.semd; MISFIT=1.557E-03
# Quantifying misfit for SOURCE_004
# 	AA.S000000.BXY.semd; MISFIT=1.830E-03
# 	AA.S000001.BXY.semd; MISFIT=1.474E-03
# 	AA.S000002.BXY.semd; MISFIT=3.435E-03
# 	AA.S000003.BXY.semd; MISFIT=1.447E-03
# 	AA.S000004.BXY.semd; MISFIT=8.716E-04
# 	AA.S000005.BXY.semd; MISFIT=1.506E-03
# 	AA.S000006.BXY.semd; MISFIT=2.867E-04
# 	AA.S000007.BXY.semd; MISFIT=2.245E-03
# 	AA.S000008.BXY.semd; MISFIT=1.698E-04
# 	AA.S000009.BXY.semd; MISFIT=2.478E-03
# Quantifying misfit for SOURCE_005
# 	AA.S000000.BXY.semd; MISFIT=2.927E-05
# 	AA.S000001.BXY.semd; MISFIT=5.372E-05
# 	AA.S000002.BXY.semd; MISFIT=3.599E-04
# 	AA.S000003.BXY.semd; MISFIT=3.011E-03
# 	AA.S000004.BXY.semd; MISFIT=1.701E-04
# 	AA.S000005.BXY.semd; MISFIT=1.421E-05
# 	AA.S000006.BXY.semd; MISFIT=3.278E-05
# 	AA.S000007.BXY.semd; MISFIT=5.119E-05
# 	AA.S000008.BXY.semd; MISFIT=2.607E-04
# 	AA.S000009.BXY.semd; MISFIT=3.931E-06
# Quantifying misfit for SOURCE_006
# 	AA.S000000.BXY.semd; MISFIT=9.769E-04
# 	AA.S000001.BXY.semd; MISFIT=1.918E-06
# 	AA.S000002.BXY.semd; MISFIT=3.380E-04
# 	AA.S000003.BXY.semd; MISFIT=3.998E-05
# 	AA.S000004.BXY.semd; MISFIT=3.727E-04
# 	AA.S000005.BXY.semd; MISFIT=1.042E-04
# 	AA.S000006.BXY.semd; MISFIT=3.353E-05
# 	AA.S000007.BXY.semd; MISFIT=7.718E-06
# 	AA.S000008.BXY.semd; MISFIT=1.053E-04
# 	AA.S000009.BXY.semd; MISFIT=4.863E-04
# Quantifying misfit for SOURCE_007
# 	AA.S000000.BXY.semd; MISFIT=2.273E-04
# 	AA.S000001.BXY.semd; MISFIT=9.695E-04
# 	AA.S000002.BXY.semd; MISFIT=4.934E-04
# 	AA.S000003.BXY.semd; MISFIT=3.203E-04
# 	AA.S000004.BXY.semd; MISFIT=1.007E-03
# 	AA.S000005.BXY.semd; MISFIT=7.716E-04
# 	AA.S000006.BXY.semd; MISFIT=1.265E-03
# 	AA.S000007.BXY.semd; MISFIT=2.117E-04
# 	AA.S000008.BXY.semd; MISFIT=1.551E-03
# 	AA.S000009.BXY.semd; MISFIT=5.167E-05
# Quantifying misfit for SOURCE_008
# 	AA.S000000.BXY.semd; MISFIT=9.690E-05
# 	AA.S000001.BXY.semd; MISFIT=7.973E-06
# 	AA.S000002.BXY.semd; MISFIT=1.467E-04
# 	AA.S000003.BXY.semd; MISFIT=2.068E-03
# 	AA.S000004.BXY.semd; MISFIT=3.275E-04
# 	AA.S000005.BXY.semd; MISFIT=8.640E-05
# 	AA.S000006.BXY.semd; MISFIT=1.805E-04
# 	AA.S000007.BXY.semd; MISFIT=9.112E-06
# 	AA.S000008.BXY.semd; MISFIT=5.279E-04
# 	AA.S000009.BXY.semd; MISFIT=2.012E-05
# Quantifying misfit for SOURCE_009
# 	AA.S000000.BXY.semd; MISFIT=4.363E-05
# 	AA.S000001.BXY.semd; MISFIT=2.189E-03
# 	AA.S000002.BXY.semd; MISFIT=4.103E-05
# 	AA.S000003.BXY.semd; MISFIT=4.012E-04
# 	AA.S000004.BXY.semd; MISFIT=1.160E-04
# 	AA.S000005.BXY.semd; MISFIT=4.449E-04
# 	AA.S000006.BXY.semd; MISFIT=2.775E-03
# 	AA.S000007.BXY.semd; MISFIT=2.852E-04
# 	AA.S000008.BXY.semd; MISFIT=1.822E-03
# 	AA.S000009.BXY.semd; MISFIT=3.354E-05
# Quantifying misfit for SOURCE_010
# 	AA.S000000.BXY.semd; MISFIT=1.377E-05
# 	AA.S000001.BXY.semd; MISFIT=7.354E-07
# 	AA.S000002.BXY.semd; MISFIT=6.179E-04
# 	AA.S000003.BXY.semd; MISFIT=2.421E-03
# 	AA.S000004.BXY.semd; MISFIT=2.176E-04
# 	AA.S000005.BXY.semd; MISFIT=1.491E-04
# 	AA.S000006.BXY.semd; MISFIT=1.443E-05
# 	AA.S000007.BXY.semd; MISFIT=2.510E-04
# 	AA.S000008.BXY.semd; MISFIT=1.467E-04
# 	AA.S000009.BXY.semd; MISFIT=2.980E-05

# %% [markdown]
# ### a) Visualizing Waveform Differences

# %%
# Plot an example of data, synthetic and adjoint source
t_init, d_init = np.loadtxt("SOURCE_001/SYNTHETIC/AA.S000000.BXY.semd").T
t_true, d_true = np.loadtxt("SOURCE_001/TARGET/AA.S000000.BXY.semd").T
t_m01, d_m01 = np.loadtxt("SOURCE_001/SYNTHETIC_01/AA.S000000.BXY.semd").T 

plot_waveforms(t=t_init, data=[d_init, d_true, d_m01],
               labels=["initial", "target", "update"],
               colors=["r", "k", "b"])

plt.title("Initial vs. Updated Model Synthetics")
plt.xlim([45, 145])
plt.show()

# %% [markdown]
# ## 11) Comparing Misfit between Initial and Updated models
# - Now we have two files containing misfit, one for the initial model, and one for the updated model (M01)
# - Each line in the misfit file corresponds to the overall misfit for a single event
# - We can compare them by taking the average of all lines in the misfit file
# - Misfit: $ \chi = \frac{1}{2} \int [d(t)-s(t)]^2 dt~$
#
# !!! TOTAL MISFIT HERE !!!

# %%
# Calculate misfit from each source
misfit_init, misfit_m01 = [], []

for src in sorted(glob("SOURCE_???")):
    m_init = np.loadtxt(os.path.join(src, "MISFIT_INIT.txt"))
    m_01 = np.loadtxt(os.path.join(src, "MISFIT_01.txt"))
    
    misfit_init.append(m_init.sum() / len(m_init))
    misfit_m01.append(m_01.sum() / len(m_01))
    
total_misfit_init = sum(misfit_init) / len(misfit_init)
total_misfit_m01 = sum(misfit_m01) / len(misfit_m01)

print(f"MISFIT INITIAL MODEL = {total_misfit_init}")
print(f"MISFIT UPDATED MODEL = {total_misfit_m01}")
print(f"MISFIT REDUCED? -> {bool(total_misfit_init > total_misfit_m01)}")
# Out:
# MISFIT INITIAL MODEL = 0.0008597683006224604
# MISFIT UPDATED MODEL = 0.0001583207458274515
# MISFIT REDUCED? -> True

# %% [markdown]
# ## 12) Final Thoughts
#
# !!! TO DO !!!

# %% [markdown]
# # Automating An Inversion using SeisFlows
#
# - Of course, now that we have gone through the rigorous manual exercise of updating a velocity model, we will show how SeisFlows automates this procedure.
# - Under the hood, SeisFlows essentialy performs what we just did, scaling the velocity model, re-running forward simulations and comparing misfit values
# - SeisFlows contains a built-in optimization library, which features gradient-descent, non-linear conjugate gradient (NLCG), and L-BFGS nonlinear optimization alogirthms
# - This library takes care of the scaling of the gradient, automating the line search and model update
# - Misfit is either calculated with the default preprocessing module, or using Pyatoa, a software designed specifically for waveform misfit quantification.

# %%
! rm -rf /home/scoped/work/day_3/sfexample_2
! mkdir -p /home/scoped/work/day_3/sfexample_2
# %cd /home/scoped/work/day_3/sfexample_2

! seisflows examples setup 2 -r /home/scoped/specfem2d --niter 1 --ntask 10 --nsta 10 --with_mpi
! seisflows par smooth_h 20000.
! seisflows par smooth_v 20000.
! seisflows submit
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# /home/scoped/work/day_3/sfexample_2
#
#                                     @@@@@@@@@@
#                                .@@@@.    .%&(  %@.
#                             @@@@   @@@@   &@@@@@@ ,%@
#                          @@@@   @@@,  /@@              @
#                         @@@   @@@@   @@@              @
#                       @@@@   @@@@   @@@                @  @
#                       @@@   @@@@   ,@@@                @ @
#                      @@@@   @@@@    @@@@              @@ @ @
#                      @@@@   @@@@@    @@@@@          @@@ @@ @
#                      @@@@    @@@@@     @@@@@@@@@@@@@@  @@  @
#                       @@@@    @@@@@@        @@@&     @@@  @
#                       @@@@@     @@@@@@@@         %@@@@#  @@
#                         @@@@#      @@@@@@@@@@@@@@@@@   @@
#                          &@@@@@          @@@@(       @@&
#                             @@@@@@@             /@@@@
#                                 @@@@@@@@@@@@@@@@@
#                                     @@@@@@@@@@
#
#
# ================================================================================
#                               SEISFLOWS EXAMPLE 2
#                               ///////////////////
# This is a [SPECFEM2D] [WORKSTATION] example, which will run an inversion to
# assess misfit between a starting homogeneous halfspace model and a target
# checkerboard model. This example problem uses the [PYAFLOWA] preprocessing
# module and the [LBFGS] optimization algorithm. In this example, windowing in
# Pyaflowa is turnd OFF.[10 events, 10 stations, 1 iterations]. The tasks involved
# include:
#
# 1. (optional) Download, configure, compile SPECFEM2D
# 2. [Setup] a SPECFEM2D working directory
# 3. [Setup] starting model from 'Tape2007' example
# 4. [Setup] target model w/ perturbed starting model
# 5. [Setup] a SeisFlows working directory
# 6. [Run] the inversion workflow
# ================================================================================
#
# ================================================================================
# EXAMPLE SETUP
# ================================================================================
# SPECFEM2D already configured, skipping 'configure'
# executables found in SPECFEM2D/bin directory, skipping 'make'
#
# ================================================================================
# GENERATING INITIAL MODEL
# ================================================================================
# > Setting the SPECFEM2D Par_file for SeisFlows compatiblility
# NPROC: 1 -> 1
# setup_with_binary_database: 0 -> 1
# SAVE_MODEL: default -> binary
# save_ASCII_kernels: .true. -> .false.
# Running SPECFEM2D with command: mpirun -n 1 bin/xmeshfem2D > OUTPUT_FILES/mesher.log.txt
# Running SPECFEM2D with command: mpirun -n 1 bin/xspecfem2D > OUTPUT_FILES/solver.log.txt
# > Cleaning up after xspecfem2d, setting up for new run
#
# ================================================================================
# GENERATING TRUE/TARGET MODEL
# ================================================================================
# > Updating SPECFEM2D to set checkerboard model as current model
# MODEL: default -> legacy
# Running SPECFEM2D with command: mpirun -n 1 bin/xmeshfem2D > OUTPUT_FILES/mesher.log.txt
# Running SPECFEM2D with command: mpirun -n 1 bin/xspecfem2D > OUTPUT_FILES/solver.log.txt
# > Cleaning up after xspecfem2d, setting up for new run
# created parameter file: parameters.yaml
# workflow: forward -> inversion
# preprocess: default -> pyaflowa
# optimize: gradient -> LBFGS
# configuring SeisFlows parameter file
# L-BFGS optimization requires 'backtrack'ing line search. Overwriting 'bracket'
# ntask: 1 -> 10
# materials: acoustic -> elastic
# density: False -> False
# data_format: ascii -> ascii
# nproc: 1 -> 1
# start: 1 -> 1
# end: 1 -> 1
# step_count_max: 10 -> 5
# data_case: data -> synthetic
# components: ZNE -> Y
# attenuation: False -> False
# 'MISFIT' not found in parameters.yaml
# 'ADJOINT' not found in parameters.yaml
# path_specfem_bin: null ->
# /home/scoped/work/day_3/sfexample_2/specfem2d_workdir/bin
# path_specfem_data: null ->
# /home/scoped/work/day_3/sfexample_2/specfem2d_workdir/DATA
# path_model_init: null ->
# /home/scoped/work/day_3/sfexample_2/specfem2d_workdir/OUTPUT_FILES_INIT
# path_model_true: null ->
# /home/scoped/work/day_3/sfexample_2/specfem2d_workdir/OUTPUT_FILES_TRUE
# mpiexec: null -> mpirun
# smooth_h: 0.0 -> 5000.0
# smooth_v: 0.0 -> 5000.0
# pyflex_preset: default -> null
# unit_output: VEL -> DISP
# min_period: 1.0 -> 10.0
# max_period: 10.0 -> 200.0
# > Finalizing SPECFEM2D Par_file for SeisFlows example
# MODEL: legacy -> gll
# use_existing_STATIONS: .false. -> .true.
# NPROC: 1 -> 1
# > Using 10 stations in this SeisFlows example
#
# ================================================================================
# COMPLETE EXAMPLE SETUP
# ================================================================================
# smooth_h: 5000.0 -> 20000.
# smooth_v: 5000.0 -> 20000.
# 2022-09-28 21:51:29 (D) | MPI executable is located at: /opt/intel/compilers_and_libraries_2020.1.217/linux/mpi/intel64/bin/mpirun
# 2022-09-28 21:51:29 (I) |
# ================================================================================
#                          SETTING UP INVERSION WORKFLOW
# ================================================================================
# 2022-09-28 21:51:36 (D) | running setup for module 'system.Workstation'
# 2022-09-28 21:51:38 (D) | copying par/log file to: /home/scoped/work/day_3/sfexample_2/logs/sflog_001.txt
# 2022-09-28 21:51:38 (D) | copying par/log file to: /home/scoped/work/day_3/sfexample_2/logs/parameters_001.yaml
# 2022-09-28 21:51:38 (D) | running setup for module 'solver.Specfem2D'
# 2022-09-28 21:51:38 (I) | initializing 10 solver directories
# 2022-09-28 21:51:38 (D) | initializing solver directory source: 001
# 2022-09-28 21:51:45 (D) | linking source '001' as 'mainsolver'
# 2022-09-28 21:51:45 (D) | initializing solver directory source: 002
# 2022-09-28 21:51:53 (D) | initializing solver directory source: 003
# 2022-09-28 21:52:00 (D) | initializing solver directory source: 004
# 2022-09-28 21:52:07 (D) | initializing solver directory source: 005
# 2022-09-28 21:52:16 (D) | initializing solver directory source: 006
# 2022-09-28 21:52:23 (D) | initializing solver directory source: 007
# 2022-09-28 21:52:27 (D) | initializing solver directory source: 008
# 2022-09-28 21:52:34 (D) | initializing solver directory source: 009
# 2022-09-28 21:52:42 (D) | initializing solver directory source: 010
# 2022-09-28 21:52:51 (D) | running setup for module 'preprocess.Pyaflowa'
# 2022-09-28 21:52:55 (D) | running setup for module 'optimize.LBFGS'
# 2022-09-28 21:52:57 (I) | no optimization checkpoint found, assuming first run
# 2022-09-28 21:52:59 (I) | re-loading optimization module from checkpoint
# 2022-09-28 21:52:59 (I) |
# ////////////////////////////////////////////////////////////////////////////////
#                               RUNNING ITERATION 01
# ////////////////////////////////////////////////////////////////////////////////
# 2022-09-28 21:52:59 (I) |
# ================================================================================
#                            RUNNING INVERSION WORKFLOW
# ================================================================================
# 2022-09-28 21:52:59 (I) |
# ////////////////////////////////////////////////////////////////////////////////
#                       EVALUATING MISFIT FOR INITIAL MODEL
# ////////////////////////////////////////////////////////////////////////////////
# 2022-09-28 21:52:59 (I) | checking initial model parameters
# 2022-09-28 21:52:59 (I) | 5800.00 <= vp <= 5800.00
# 2022-09-28 21:52:59 (I) | 3500.00 <= vs <= 3500.00
# 2022-09-28 21:52:59 (I) | 2600.00 <= rho <= 2600.00
# 2022-09-28 21:52:59 (I) | checking true/target model parameters
# 2022-09-28 21:52:59 (I) | 5526.10 <= vp <= 6088.50
# 2022-09-28 21:52:59 (I) | 3150.10 <= vs <= 3849.90
# 2022-09-28 21:52:59 (I) | 2600.00 <= rho <= 2600.00
# 2022-09-28 21:52:59 (I) | preparing observation data for source 001
# 2022-09-28 21:52:59 (I) | running forward simulation w/ target model for 001
# 2022-09-28 21:52:59 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:52:59 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:53:07 (I) | evaluating objective function for source 001
# 2022-09-28 21:53:07 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 21:53:07 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:53:08 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:53:16 (D) | quantifying misfit with 'Pyaflowa'
# [2022-09-28 21:53:16] - pyatoa - WARNING: No origintime given, setting to default 1970-01-01T00:00:00
# 2022-09-28 21:53:21 (I) | preparing observation data for source 002
# 2022-09-28 21:53:21 (I) | running forward simulation w/ target model for 002
# 2022-09-28 21:53:21 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:53:22 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:53:30 (I) | evaluating objective function for source 002
# 2022-09-28 21:53:30 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 21:53:30 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:53:31 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:53:39 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 21:53:45 (I) | preparing observation data for source 003
# 2022-09-28 21:53:45 (I) | running forward simulation w/ target model for 003
# 2022-09-28 21:53:45 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:53:45 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:53:55 (I) | evaluating objective function for source 003
# 2022-09-28 21:53:55 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 21:53:55 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:53:56 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:54:10 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 21:54:17 (I) | preparing observation data for source 004
# 2022-09-28 21:54:17 (I) | running forward simulation w/ target model for 004
# 2022-09-28 21:54:17 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:54:18 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:54:29 (I) | evaluating objective function for source 004
# 2022-09-28 21:54:29 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 21:54:29 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:54:30 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:54:43 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 21:54:50 (I) | preparing observation data for source 005
# 2022-09-28 21:54:50 (I) | running forward simulation w/ target model for 005
# 2022-09-28 21:54:50 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:54:51 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:55:01 (I) | evaluating objective function for source 005
# 2022-09-28 21:55:01 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 21:55:01 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:55:02 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:55:13 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 21:55:19 (I) | preparing observation data for source 006
# 2022-09-28 21:55:19 (I) | running forward simulation w/ target model for 006
# 2022-09-28 21:55:19 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:55:19 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:55:29 (I) | evaluating objective function for source 006
# 2022-09-28 21:55:29 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 21:55:29 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:55:29 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:55:38 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 21:55:44 (I) | preparing observation data for source 007
# 2022-09-28 21:55:44 (I) | running forward simulation w/ target model for 007
# 2022-09-28 21:55:44 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:55:45 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:55:53 (I) | evaluating objective function for source 007
# 2022-09-28 21:55:53 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 21:55:53 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:55:54 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:56:03 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 21:56:08 (I) | preparing observation data for source 008
# 2022-09-28 21:56:08 (I) | running forward simulation w/ target model for 008
# 2022-09-28 21:56:08 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:56:09 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:56:17 (I) | evaluating objective function for source 008
# 2022-09-28 21:56:17 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 21:56:17 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:56:18 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:56:26 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 21:56:31 (I) | preparing observation data for source 009
# 2022-09-28 21:56:31 (I) | running forward simulation w/ target model for 009
# 2022-09-28 21:56:31 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:56:32 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:56:40 (I) | evaluating objective function for source 009
# 2022-09-28 21:56:40 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 21:56:40 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:56:41 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:56:49 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 21:56:55 (I) | preparing observation data for source 010
# 2022-09-28 21:56:55 (I) | running forward simulation w/ target model for 010
# 2022-09-28 21:56:55 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:56:56 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:57:05 (I) | evaluating objective function for source 010
# 2022-09-28 21:57:05 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 21:57:05 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 21:57:06 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:57:14 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 21:57:19 (I) |
# ////////////////////////////////////////////////////////////////////////////////
#                 EVALUATING EVENT KERNELS W/ ADJOINT SIMULATIONS
# ////////////////////////////////////////////////////////////////////////////////
# 2022-09-28 21:57:19 (I) | running adjoint simulation for source 001
# 2022-09-28 21:57:19 (I) | running SPECFEM executable bin/xspecfem2D, log to 'adj_solver.log'
# 2022-09-28 21:57:19 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:57:43 (D) | renaming output event kernels: 'alpha' -> 'vp'
# 2022-09-28 21:57:43 (D) | renaming output event kernels: 'beta' -> 'vs'
# 2022-09-28 21:57:44 (I) | running adjoint simulation for source 002
# 2022-09-28 21:57:44 (I) | running SPECFEM executable bin/xspecfem2D, log to 'adj_solver.log'
# 2022-09-28 21:57:44 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:58:08 (D) | renaming output event kernels: 'alpha' -> 'vp'
# 2022-09-28 21:58:08 (D) | renaming output event kernels: 'beta' -> 'vs'
# 2022-09-28 21:58:09 (I) | running adjoint simulation for source 003
# 2022-09-28 21:58:09 (I) | running SPECFEM executable bin/xspecfem2D, log to 'adj_solver.log'
# 2022-09-28 21:58:09 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:58:34 (D) | renaming output event kernels: 'alpha' -> 'vp'
# 2022-09-28 21:58:34 (D) | renaming output event kernels: 'beta' -> 'vs'
# 2022-09-28 21:58:35 (I) | running adjoint simulation for source 004
# 2022-09-28 21:58:35 (I) | running SPECFEM executable bin/xspecfem2D, log to 'adj_solver.log'
# 2022-09-28 21:58:35 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:59:01 (D) | renaming output event kernels: 'alpha' -> 'vp'
# 2022-09-28 21:59:01 (D) | renaming output event kernels: 'beta' -> 'vs'
# 2022-09-28 21:59:02 (I) | running adjoint simulation for source 005
# 2022-09-28 21:59:02 (I) | running SPECFEM executable bin/xspecfem2D, log to 'adj_solver.log'
# 2022-09-28 21:59:02 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:59:28 (D) | renaming output event kernels: 'alpha' -> 'vp'
# 2022-09-28 21:59:28 (D) | renaming output event kernels: 'beta' -> 'vs'
# 2022-09-28 21:59:30 (I) | running adjoint simulation for source 006
# 2022-09-28 21:59:30 (I) | running SPECFEM executable bin/xspecfem2D, log to 'adj_solver.log'
# 2022-09-28 21:59:30 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 21:59:57 (D) | renaming output event kernels: 'alpha' -> 'vp'
# 2022-09-28 21:59:57 (D) | renaming output event kernels: 'beta' -> 'vs'
# 2022-09-28 21:59:58 (I) | running adjoint simulation for source 007
# 2022-09-28 21:59:58 (I) | running SPECFEM executable bin/xspecfem2D, log to 'adj_solver.log'
# 2022-09-28 21:59:58 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:00:22 (D) | renaming output event kernels: 'alpha' -> 'vp'
# 2022-09-28 22:00:22 (D) | renaming output event kernels: 'beta' -> 'vs'
# 2022-09-28 22:00:24 (I) | running adjoint simulation for source 008
# 2022-09-28 22:00:24 (I) | running SPECFEM executable bin/xspecfem2D, log to 'adj_solver.log'
# 2022-09-28 22:00:24 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:00:49 (D) | renaming output event kernels: 'alpha' -> 'vp'
# 2022-09-28 22:00:49 (D) | renaming output event kernels: 'beta' -> 'vs'
# 2022-09-28 22:00:51 (I) | running adjoint simulation for source 009
# 2022-09-28 22:00:51 (I) | running SPECFEM executable bin/xspecfem2D, log to 'adj_solver.log'
# 2022-09-28 22:00:51 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:01:14 (D) | renaming output event kernels: 'alpha' -> 'vp'
# 2022-09-28 22:01:14 (D) | renaming output event kernels: 'beta' -> 'vs'
# 2022-09-28 22:01:14 (I) | running adjoint simulation for source 010
# 2022-09-28 22:01:14 (I) | running SPECFEM executable bin/xspecfem2D, log to 'adj_solver.log'
# 2022-09-28 22:01:14 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:01:36 (D) | renaming output event kernels: 'alpha' -> 'vp'
# 2022-09-28 22:01:36 (D) | renaming output event kernels: 'beta' -> 'vs'
# 2022-09-28 22:01:38 (I) |
# ////////////////////////////////////////////////////////////////////////////////
#                       GENERATING/PROCESSING MISFIT KERNEL
# ////////////////////////////////////////////////////////////////////////////////
# 2022-09-28 22:01:38 (I) | combining event kernels into single misfit kernel
# 2022-09-28 22:01:39 (D) | running executable with cmd: 'mpirun -n 1 bin/xcombine_sem vp_kernel kernel_paths /home/scoped/work/day_3/sfexample_2/scratch/eval_grad/misfit_kernel'
# 2022-09-28 22:01:39 (D) | running executable with cmd: 'mpirun -n 1 bin/xcombine_sem vs_kernel kernel_paths /home/scoped/work/day_3/sfexample_2/scratch/eval_grad/misfit_kernel'
# 2022-09-28 22:01:40 (I) | smoothing misfit kernel: H=20000.0; V=20000.0
# 2022-09-28 22:01:40 (D) | smoothing ['vp', 'vs'] with horizontal Gaussian 20000.0m and vertical Gaussian 20000.0m
# 2022-09-28 22:01:40 (D) | running executable with cmd: 'mpirun -n 1 bin/xsmooth_sem 20000.0 20000.0 vp_kernel /home/scoped/work/day_3/sfexample_2/scratch/eval_grad/mk_nosmooth/ /home/scoped/work/day_3/sfexample_2/scratch/eval_grad/misfit_kernel/ .false'
# 2022-09-28 22:01:57 (D) | running executable with cmd: 'mpirun -n 1 bin/xsmooth_sem 20000.0 20000.0 vs_kernel /home/scoped/work/day_3/sfexample_2/scratch/eval_grad/mk_nosmooth/ /home/scoped/work/day_3/sfexample_2/scratch/eval_grad/misfit_kernel/ .false'
# 2022-09-28 22:02:25 (I) | scaling gradient to absolute model perturbations
# 2022-09-28 22:02:26 (I) | exporting gradient to disk
# 2022-09-28 22:02:26 (D) | /home/scoped/work/day_3/sfexample_2/output/gradient -> /home/scoped/work/day_3/sfexample_2/output/GRADIENT_01
# 2022-09-28 22:02:26 (I) |
# ////////////////////////////////////////////////////////////////////////////////
#                               RUNNING LINE SEARCH
# ////////////////////////////////////////////////////////////////////////////////
# 2022-09-28 22:02:26 (I) | initializing 'Backtrack'ing line search
# 2022-09-28 22:02:26 (I) | first L-BFGS iteration, default to 'Gradient' descent
# 2022-09-28 22:02:26 (I) | enforcing max step length safeguard
# 2022-09-28 22:02:26 (D) | step length(s) = 0.00E+00
# 2022-09-28 22:02:26 (D) | misfit val(s)  = 2.11E+01
# 2022-09-28 22:02:26 (I) | try: first evaluation, attempt guess step length, alpha=6.61E+02
# 2022-09-28 22:02:26 (D) | overwriting initial step length, alpha_new=4.47E+05
# 2022-09-28 22:02:26 (I) | trial model 'm_try' parameters:
# 2022-09-28 22:02:26 (I) | 5800.00 <= vp <= 5800.00
# 2022-09-28 22:02:26 (I) | 3210.00 <= vs <= 3697.05
# 2022-09-28 22:02:27 (I) |
# LINE SEARCH STEP COUNT 01
# --------------------------------------------------------------------------------
# 2022-09-28 22:02:27 (I) | evaluating objective function for source 001
# 2022-09-28 22:02:27 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:02:27 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:02:27 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:02:39 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:02:45 (I) | evaluating objective function for source 002
# 2022-09-28 22:02:45 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:02:45 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:02:46 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:02:55 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:03:00 (I) | evaluating objective function for source 003
# 2022-09-28 22:03:00 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:03:00 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:03:01 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:03:11 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:03:16 (I) | evaluating objective function for source 004
# 2022-09-28 22:03:16 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:03:16 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:03:17 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:03:27 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:03:33 (I) | evaluating objective function for source 005
# 2022-09-28 22:03:33 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:03:33 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:03:34 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:03:47 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:03:54 (I) | evaluating objective function for source 006
# 2022-09-28 22:03:54 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:03:54 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:03:54 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:04:09 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:04:16 (I) | evaluating objective function for source 007
# 2022-09-28 22:04:16 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:04:16 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:04:17 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:04:26 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:04:31 (I) | evaluating objective function for source 008
# 2022-09-28 22:04:31 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:04:31 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:04:32 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:04:40 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:04:46 (I) | evaluating objective function for source 009
# 2022-09-28 22:04:46 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:04:46 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:04:46 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:04:55 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:05:02 (I) | evaluating objective function for source 010
# 2022-09-28 22:05:02 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:05:02 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:05:03 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:05:14 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:05:21 (D) | misfit for trial model (f_try) == 0.00E+00
# 2022-09-28 22:05:21 (D) | step length(s) = 0.00E+00, 4.47E+05
# 2022-09-28 22:05:21 (D) | misfit val(s)  = 2.11E+01, 0.00E+00
# 2022-09-28 22:05:21 (I) | try: misfit not bracketed, increasing step length using golden ratio, alpha=7.22E+05
# 2022-09-28 22:05:21 (I) | line search model 'm_try' parameters:
# 2022-09-28 22:05:21 (I) | 5800.00 <= vp <= 5800.00
# 2022-09-28 22:05:21 (I) | 3030.77 <= vs <= 3818.83
# 2022-09-28 22:05:21 (I) | trial step unsuccessful. re-attempting line search
# 2022-09-28 22:05:21 (I) |
# LINE SEARCH STEP COUNT 02
# --------------------------------------------------------------------------------
# 2022-09-28 22:05:21 (I) | evaluating objective function for source 001
# 2022-09-28 22:05:21 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:05:21 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:05:21 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:05:32 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:05:39 (I) | evaluating objective function for source 002
# 2022-09-28 22:05:39 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:05:39 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:05:40 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:05:51 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:06:00 (I) | evaluating objective function for source 003
# 2022-09-28 22:06:00 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:06:00 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:06:01 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:06:17 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:06:26 (I) | evaluating objective function for source 004
# 2022-09-28 22:06:26 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:06:26 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:06:27 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:06:41 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:06:53 (I) | evaluating objective function for source 005
# 2022-09-28 22:06:53 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:06:53 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:06:54 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:07:12 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:07:20 (I) | evaluating objective function for source 006
# 2022-09-28 22:07:20 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:07:20 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:07:21 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:07:38 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:07:46 (I) | evaluating objective function for source 007
# 2022-09-28 22:07:46 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:07:46 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:07:47 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:08:00 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:08:08 (I) | evaluating objective function for source 008
# 2022-09-28 22:08:08 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:08:08 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:08:08 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:08:21 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:08:35 (I) | evaluating objective function for source 009
# 2022-09-28 22:08:35 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:08:35 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:08:36 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:08:49 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:08:58 (I) | evaluating objective function for source 010
# 2022-09-28 22:08:58 (D) | running forward simulation with 'Specfem2D'
# 2022-09-28 22:08:58 (D) | running executable with cmd: 'mpirun -n 1 bin/xmeshfem2D'
# 2022-09-28 22:08:58 (D) | running executable with cmd: 'mpirun -n 1 bin/xspecfem2D'
# 2022-09-28 22:09:10 (D) | quantifying misfit with 'Pyaflowa'
# 2022-09-28 22:09:18 (D) | misfit for trial model (f_try) == 3.20E+00
# 2022-09-28 22:09:18 (D) | step length(s) = 0.00E+00, 4.47E+05, 7.22E+05
# 2022-09-28 22:09:18 (D) | misfit val(s)  = 2.11E+01, 0.00E+00, 3.20E+00
# 2022-09-28 22:09:18 (I) | pass: bracket acceptable and step length reasonable. returning minimum line search misfit.
# 2022-09-28 22:09:18 (I) | line search model 'm_try' parameters:
# 2022-09-28 22:09:18 (I) | 5800.00 <= vp <= 5800.00
# 2022-09-28 22:09:18 (I) | 3210.00 <= vs <= 3697.05
# 2022-09-28 22:09:18 (I) | trial step successful. finalizing line search
# 2022-09-28 22:09:18 (I) |
# FINALIZING LINE SEARCH
# --------------------------------------------------------------------------------
# 2022-09-28 22:09:18 (I) | writing optimization stats
# 2022-09-28 22:09:18 (I) | renaming current (new) optimization vectors as previous model (old)
# 2022-09-28 22:09:18 (I) | setting accepted trial model (try) as current model (new)
# 2022-09-28 22:09:18 (I) | misfit of accepted trial model is f=0.000E+00
# 2022-09-28 22:09:18 (I) | resetting line search step count to 0
# 2022-09-28 22:09:18 (I) |
# CLEANING WORKDIR FOR NEXT ITERATION
# --------------------------------------------------------------------------------
# 2022-09-28 22:09:20 (I) | thrifty inversion encountering first iteration, defaulting to standard inversion workflow
# 2022-09-28 22:09:23 (I) |
# ////////////////////////////////////////////////////////////////////////////////
#                              COMPLETE ITERATION 01
# ////////////////////////////////////////////////////////////////////////////////
# 2022-09-28 22:09:23 (I) | setting current iteration to: 2

# %% [markdown]
# -------------
#
# The task will be finished when you see the log message:
#
# ```bash
# ////////////////////////////////////////////////////////////////////////////////
#                              COMPLETE ITERATION 01
# ////////////////////////////////////////////////////////////////////////////////
# 2022-09-16 21:25:38 (I) | setting current iteration to: 2
# ```

# %%
! echo "> output/ contains models, gradients, etc."
! ls output
! echo

! echo "> MODEL directories contain SPECFEM formatted model files"
! ls output/MODEL_INIT
! echo

! echo "> GRADIENT directories contain regularized misfit kernels"
! ls output/GRADIENT_01
! echo
# Out:
# > output/ contains models, gradients, etc.
# GRADIENT_01  MODEL_01  MODEL_INIT  MODEL_TRUE  pyaflowa
#
# > MODEL directories contain SPECFEM formatted model files
# proc000000_vp.bin  proc000000_vs.bin  proc000000_x.bin	proc000000_z.bin
#
# > GRADIENT directories contain regularized misfit kernels
# proc000000_vp_kernel.bin  proc000000_vs_kernel.bin

# %%
# Models/gradients can be plotted directly from the command line
! seisflows plot2d MODEL_01 vs --savefig m_01_vs.png
Image("m_01_vs.png")
# Out:
# Figure(707.107x707.107)
